# %% [markdown]
# ## Plotting With Pandas

# %%
import math
import collections
import urllib


import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
#sets the maximum number of rows for the data output in pandas
pd.options.display.max_rows = 15

# %%
gapminder = pd.read_csv('gapminder.csv')
gapminder
# Out:
#            country  year  region  population  life_expectancy  age5_surviving  \
# 0      Afghanistan  1800    Asia   3280000.0            28.21          53.142
# 1      Afghanistan  1810    Asia   3280000.0            28.11          53.002
# 2      Afghanistan  1820    Asia   3323519.0            28.01          52.862
# 3      Afghanistan  1830    Asia   3448982.0            27.90          52.719
# 4      Afghanistan  1840    Asia   3625022.0            27.80          52.576
# ...            ...   ...     ...         ...              ...             ...
# 14735     Zimbabwe  2011  Africa  14255592.0            51.60          90.800
# 14736     Zimbabwe  2012  Africa  14565482.0            54.20          91.330
# 14737     Zimbabwe  2013  Africa  14898092.0            55.70          91.670
# 14738     Zimbabwe  2014  Africa  15245855.0            57.00          91.900
# 14739     Zimbabwe  2015  Africa  15602751.0            59.30          92.040
#
#        babies_per_woman  gdp_per_capita
# 0                  7.00           603.0
# 1                  7.00           604.0
# 2                  7.00           604.0
# 3                  7.00           625.0
# 4                  7.00           647.0
# ...                 ...             ...
# 14735              3.64          1626.0
# 14736              3.56          1750.0
# 14737              3.49          1773.0
# 14738              3.41          1773.0
# 14739              3.35          1801.0
#
# [14740 rows x 8 columns]

# %%
gapminder.head()
# Out:
#        country  year region  population  life_expectancy  age5_surviving  \
# 0  Afghanistan  1800   Asia   3280000.0            28.21          53.142
# 1  Afghanistan  1810   Asia   3280000.0            28.11          53.002
# 2  Afghanistan  1820   Asia   3323519.0            28.01          52.862
# 3  Afghanistan  1830   Asia   3448982.0            27.90          52.719
# 4  Afghanistan  1840   Asia   3625022.0            27.80          52.576
#
#    babies_per_woman  gdp_per_capita
# 0               7.0           603.0
# 1               7.0           604.0
# 2               7.0           604.0
# 3               7.0           625.0
# 4               7.0           647.0

# %%
gapminder.tail()
# Out:
#         country  year  region  population  life_expectancy  age5_surviving  \
# 14735  Zimbabwe  2011  Africa  14255592.0             51.6           90.80
# 14736  Zimbabwe  2012  Africa  14565482.0             54.2           91.33
# 14737  Zimbabwe  2013  Africa  14898092.0             55.7           91.67
# 14738  Zimbabwe  2014  Africa  15245855.0             57.0           91.90
# 14739  Zimbabwe  2015  Africa  15602751.0             59.3           92.04
#
#        babies_per_woman  gdp_per_capita
# 14735              3.64          1626.0
# 14736              3.56          1750.0
# 14737              3.49          1773.0
# 14738              3.41          1773.0
# 14739              3.35          1801.0

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14740 entries, 0 to 14739
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           14740 non-null  object
#  1   year              14740 non-null  int64
#  2   region            14740 non-null  object
#  3   population        14740 non-null  float64
#  4   life_expectancy   14740 non-null  float64
#  5   age5_surviving    14740 non-null  float64
#  6   babies_per_woman  14740 non-null  float64
#  7   gdp_per_capita    14740 non-null  float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 921.4+ KB

# %%
gapminder.describe()
# Out:
#                year    population  life_expectancy  age5_surviving  \
# count  14740.000000  1.474000e+04     14740.000000    14740.000000
# mean    1961.687924  2.252933e+07        56.834526       84.452665
# std       50.480650  9.307143e+07        15.868464       14.472179
# min     1800.000000  2.128000e+03         4.000000       33.217000
# 25%     1955.000000  8.990308e+05        44.230000       75.182250
# 50%     1975.000000  4.063978e+06        60.080000       89.693000
# 75%     1995.000000  1.218722e+07        70.380000       96.870000
# max     2015.000000  1.376049e+09        83.300000       99.810000
#
#        babies_per_woman  gdp_per_capita
# count      14740.000000    14740.000000
# mean           4.643472     9000.506513
# std            1.994833    14912.146692
# min            1.130000      142.000000
# 25%            2.630000     1391.000000
# 50%            5.060000     3509.000000
# 75%            6.440000    10244.000000
# max            9.220000   182668.000000

# %%
#Adding an extra column to the Pandas DataFrame dataset for gapminder
gapminder['log_gdp_per_day'] = np.log10(gapminder['gdp_per_capita']/365.25)

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14740 entries, 0 to 14739
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   country           14740 non-null  object
#  1   year              14740 non-null  int64
#  2   region            14740 non-null  object
#  3   population        14740 non-null  float64
#  4   life_expectancy   14740 non-null  float64
#  5   age5_surviving    14740 non-null  float64
#  6   babies_per_woman  14740 non-null  float64
#  7   gdp_per_capita    14740 non-null  float64
#  8   log_gdp_per_day   14740 non-null  float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 1.0+ MB

# %%
gapminder_by_year = gapminder.set_index('year').sort_index()
gapminder_by_year
# Out:
#             country   region   population  life_expectancy  age5_surviving  \
# year
# 1800    Afghanistan     Asia    3280000.0            28.21          53.142
# 1800         Guyana  America     166034.0            31.12          57.084
# 1800  Guinea-Bissau   Africa     218167.0            32.00          58.256
# 1800         Guinea   Africa     983959.0            29.50          54.940
# 1800      Guatemala  America     458965.0            25.80          49.664
# ...             ...      ...          ...              ...             ...
# 2015    Philippines     Asia  100699395.0            71.00          97.200
# 2015           Peru  America   31376670.0            79.50          98.310
# 2015       Paraguay  America    6639123.0            74.40          97.950
# 2015     Seychelles   Africa      96471.0            74.10          98.640
# 2015       Zimbabwe   Africa   15602751.0            59.30          92.040
#
#       babies_per_woman  gdp_per_capita  log_gdp_per_day
# year
# 1800              7.00           603.0         0.217727
# 1800              5.01          1214.0         0.521628
# 1800              7.25           777.0         0.327831
# 1800              6.11           450.0         0.090622
# 1800              6.45           857.0         0.370391
# ...                ...             ...              ...
# 2015              2.98          6876.0         1.274746
# 2015              2.36         11903.0         1.513066
# 2015              2.80          8219.0         1.352229
# 2015              2.13         25684.0         1.847072
# 2015              3.35          1801.0         0.692923
#
# [14740 rows x 8 columns]

# %%
gapminder_by_country = gapminder.set_index('country').sort_index()
gapminder_by_country
# Out:
#              year  region  population  life_expectancy  age5_surviving  \
# country
# Afghanistan  1800    Asia   3280000.0            28.21          53.142
# Afghanistan  1993    Asia  14824371.0            49.50          83.800
# Afghanistan  1992    Asia  13745630.0            49.40          83.220
# Afghanistan  1991    Asia  12789374.0            49.30          82.580
# Afghanistan  1990    Asia  12067570.0            49.50          81.900
# ...           ...     ...         ...              ...             ...
# Zimbabwe     1958  Africa   3519806.0            52.17          84.050
# Zimbabwe     1957  Africa   3410611.0            51.71          83.600
# Zimbabwe     1956  Africa   3305403.0            51.22          83.200
# Zimbabwe     1953  Africa   3010186.0            49.75          81.930
# Zimbabwe     2015  Africa  15602751.0            59.30          92.040
#
#              babies_per_woman  gdp_per_capita  log_gdp_per_day
# country
# Afghanistan              7.00           603.0         0.217727
# Afghanistan              7.76           810.0         0.345895
# Afghanistan              7.73           941.0         0.410999
# Afghanistan              7.70          1022.0         0.446861
# Afghanistan              7.69          1028.0         0.449403
# ...                       ...             ...              ...
# Zimbabwe                 7.04          1920.0         0.720711
# Zimbabwe                 6.98          1941.0         0.725435
# Zimbabwe                 6.93          1843.0         0.702935
# Zimbabwe                 6.81          1618.0         0.646388
# Zimbabwe                 3.35          1801.0         0.692923
#
# [14740 rows x 8 columns]

# %%
gapminder_by_year.loc[2005].plot.scatter('log_gdp_per_day','life_expectancy')
pp.show()

# %%
axes = gapminder_by_year.loc[1960].plot.scatter('log_gdp_per_day','life_expectancy',label = 1960)
gapminder_by_year.loc[2015].plot.scatter('log_gdp_per_day','life_expectancy',label= 2015, color = 'C1', ax = axes)
pp.show()

# %%
gdp_gapminder = gapminder[['life_expectancy','log_gdp_per_day']]
gdp_gapminder.plot.scatter('life_expectancy','log_gdp_per_day')
pp.show()

# %%
gapminder_by_country.loc['Italy'].plot('year','life_expectancy')
pp.show()

# %%
gapminder_by_country.loc['Italy'].sort_values('year').plot('year','life_expectancy')
pp.show()

# %%
#Comparing three different countries
axes = gapminder_by_country.loc['Italy'].sort_values('year').plot('year','life_expectancy', label='Italy')
gapminder_by_country.loc['China'].sort_values('year').plot('year','life_expectancy',label='China',ax = axes)
gapminder_by_country.loc['United States'].sort_values('year').plot('year','life_expectancy',label='USA',ax = axes)

pp.axis(xmin = 1900)
pp.ylabel('Life Expectancy')
pp.xlabel('Years')

pp.show()

# %%
#What happened to China in the year 1960 - Disastrous famine

# %%
#To determine the fertility rate and Life expectancy up to the age of 5 (Globally)
gapminder.babies_per_woman.mean()
# Out:
# 4.643471506105837

# %%
gapminder.groupby('year').babies_per_woman.mean()
#Women are having fewer babies nowadays compared to the past.
# Out:
# year
# 1800    6.105028
# 1810    6.094254
# 1820    6.094396
# 1830    6.085879
# 1840    6.072802
#           ...
# 2011    2.925110
# 2012    2.892912
# 2013    2.863407
# 2014    2.830934
# 2015    2.799231
# Name: babies_per_woman, Length: 81, dtype: float64

# %%
gapminder.groupby('year').babies_per_woman.mean().plot()
pp.ylabel('Babies per Woman')
pp.show()

# %%
gapminder.groupby('year').age5_surviving.mean().plot(secondary_y = True)
pp.ylabel('Age 5 survival [%]')
pp.show()
#There is a rising trend in the survival rate. This could be attributed to 
# the advancement in medical care as well as better nourishment plans for nursing
# mothers with improved GDP_per_capita

# %%
gapminder.groupby('year').babies_per_woman.mean().plot()
pp.ylabel('Babies per Woman')

gapminder.groupby('year').age5_surviving.mean().plot(secondary_y = True)
pp.ylabel('Age 5 survival [%]')

pp.show()

# %%
gapminder.pivot_table('babies_per_woman','year','region')
# Out:
# region    Africa   America      Asia    Europe
# year
# 1800    6.393208  6.055758  6.291923  5.561628
# 1810    6.394151  6.040000  6.281154  5.540233
# 1820    6.394340  6.031515  6.292692  5.545909
# 1830    6.395472  6.046364  6.285577  5.506591
# 1840    6.396226  6.046970  6.255577  5.486591
# ...          ...       ...       ...       ...
# 2011    4.569811  2.340000  2.736923  1.605227
# 2012    4.508868  2.315152  2.700769  1.606818
# 2013    4.447547  2.294242  2.664038  1.617727
# 2014    4.383962  2.269697  2.627692  1.621364
# 2015    4.319245  2.247576  2.592115  1.626818
#
# [81 rows x 4 columns]

# %%
gapminder.pivot_table('babies_per_woman','year','region').plot()
pp.show()
#Africa leads in number of babies per woman while Europe is tailing

# %%
gapminder.pivot_table('age5_surviving','year','region')
# Out:
# region     Africa    America       Asia     Europe
# year
# 1800    56.186075  56.714818  55.496692  62.050535
# 1810    56.295792  57.314727  55.770808  62.857535
# 1820    56.397962  57.880000  56.056692  63.528227
# 1830    56.493151  58.428485  56.399442  63.647614
# 1840    56.581868  59.150182  56.632923  64.210318
# ...           ...        ...        ...        ...
# 2011    91.856415  97.923333  97.006731  99.240000
# 2012    92.190000  97.981515  97.112308  99.274545
# 2013    92.490189  98.042121  97.214038  99.305227
# 2014    92.760943  98.100303  97.310962  99.332045
# 2015    92.999434  98.156667  97.404615  99.356818
#
# [81 rows x 4 columns]

# %%
gapminder.pivot_table('age5_surviving','year','region').plot()
pp.show()

#The trend shows that in Europe there is higher life expectancy of babies surviving up to the age of 5 years
# while the figures in Africa are the lowest. There is a link to the GDP and economic prosperity of the two regions

# %% [markdown]
# ### EOD
